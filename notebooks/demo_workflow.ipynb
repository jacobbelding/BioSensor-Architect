# %% [markdown]
# # BioSensor-Architect Demo Workflow
#
# This notebook walks through a complete genetic construct design workflow,
# from user query to final design report with characterization plan.
#
# ## Example: Design a nitrate sensor for *Arabidopsis thaliana*

# %%
# TODO: Import and run the orchestration workflow
# from biosensor_architect.orchestration.workflow import build_workflow
